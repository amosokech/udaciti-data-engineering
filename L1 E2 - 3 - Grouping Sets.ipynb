# %% [markdown]
# # Exercise 02 -  OLAP Cubes - Grouping Sets

# %% [markdown]
# All the databases table in this demo are based on public database samples and transformations
# - `Sakila` is a sample database created by `MySql` [Link](https://dev.mysql.com/doc/sakila/en/sakila-structure.html)
# - The postgresql version of it is called `Pagila` [Link](https://github.com/devrimgunduz/pagila)
# - The facts and dimension tables design is based on O'Reilly's public dimensional modelling tutorial schema [Link](http://archive.oreilly.com/oreillyschool/courses/dba3/index.html)
#
# Start by connecting to the database by running the cells below. If you are coming back to this exercise, then uncomment and run the first cell to recreate the database. If you recently completed the slicing and dicing exercise, then skip to the second cell.

# %%
# !PGPASSWORD=student createdb -h 127.0.0.1 -U student pagila_star
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila_star -f Data/pagila-star.sql
# Out:
#  set_config
# ------------
#
# (1 row)
#
#  setval
# --------
#     200
# (1 row)
#
#  setval
# --------
#     605
# (1 row)
#
#  setval
# --------
#      16
# (1 row)
#
#  setval
# --------
#     600
# (1 row)
#
#  setval
# --------
#     109
# (1 row)
#
#  setval
# --------
#     599
# (1 row)
#
#  setval
# --------
#       1
# (1 row)
#
#  setval
# --------
#       1
# (1 row)
#
#  setval
# --------
#       1
# (1 row)
#
#  setval
# --------
#       1
# (1 row)
#
#  setval
# --------
#   16049
# (1 row)
#
#  setval
# --------
#    1000
# (1 row)
#
#  setval
# --------
#    4581
# (1 row)
#
#  setval
# --------
#       6
# (1 row)
#
#  setval
# --------
#   32098
# (1 row)
#
#  setval
# --------
#   16049
# (1 row)
#
#  setval
# --------
#       2
# (1 row)
#
#  setval
# --------
#       2
# (1 row)

# %% [markdown]
# ### Connect to the local database where Pagila is loaded

# %%
import sql
# %load_ext sql

DB_ENDPOINT = "127.0.0.1"
DB = 'pagila_star'
DB_USER = 'student'
DB_PASSWORD = 'student'
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# %sql $conn_string
# Out:
# postgresql://student:student@127.0.0.1:5432/pagila_star
# 'Connected: student@pagila_star'

# %% [markdown]
# ### Star Schema

# %% [markdown]
# <img src="pagila-star.png" width="50%"/>

# %% [markdown]
# # Grouping Sets
# - It happens often that for 3 dimensions, you want to aggregate a fact:
#     - by nothing (total)
#     - then by the 1st dimension
#     - then by the 2nd
#     - then by the 3rd
#     - then by the 1st and 2nd
#     - then by the 2nd and 3rd
#     - then by the 1st and 3rd
#     - then by the 1st and 2nd and 3rd
#
# - Since this is very common, and in all cases, we are iterating through all the fact table anyhow, there is a more clever way to do that using the SQL grouping statement "GROUPING SETS"

# %% [markdown]
# ## Total Revenue
#
# TODO: Write a query that calculates total revenue (sales_amount)

# %%
# %%sql
# SELECT sum(sales_amount) revenue
# FROM factsales;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 1 rows affected.
# [(Decimal('67416.51'),)]

# %% [markdown]
# ## Revenue by Country
# TODO: Write a query that calculates total revenue (sales_amount) by country

# %%
# %%sql
# SELECT c.country, sum(s.sales_amount) as revenue
# FROM factsales s
# JOIN dimcustomer c ON (s.customer_key = c.customer_key)
# GROUP BY country
# ORDER BY revenue desc;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 108 rows affected.
# [('India', Decimal('6630.27')),
#  ('China', Decimal('5802.73')),
#  ('United States', Decimal('4110.32')),
#  ('Japan', Decimal('3471.74')),
#  ('Mexico', Decimal('3307.04')),
#  ('Brazil', Decimal('3200.52')),
#  ('Russian Federation', Decimal('3045.87')),
#  ('Philippines', Decimal('2381.32')),
#  ('Turkey', Decimal('1662.12')),
#  ('Nigeria', Decimal('1511.48')),
#  ('Indonesia', Decimal('1510.33')),
#  ('Argentina', Decimal('1434.48')),
#  ('Taiwan', Decimal('1210.94')),
#  ('South Africa', Decimal('1204.15')),
#  ('Iran', Decimal('950.75')),
#  ('United Kingdom', Decimal('924.80')),
#  ('Poland', Decimal('877.97')),
#  ('Italy', Decimal('831.11')),
#  ('Germany', Decimal('831.04')),
#  ('Vietnam', Decimal('746.28')),
#  ('Ukraine', Decimal('730.42')),
#  ('Colombia', Decimal('709.41')),
#  ('Egypt', Decimal('694.39')),
#  ('Venezuela', Decimal('683.30')),
#  ('Spain', Decimal('606.58')),
#  ('Canada', Decimal('593.63')),
#  ('Netherlands', Decimal('586.66')),
#  ('South Korea', Decimal('574.65')),
#  ('Pakistan', Decimal('525.72')),
#  ('Saudi Arabia', Decimal('523.79')),
#  ('Yemen', Decimal('510.83')),
#  ('Peru', Decimal('468.88')),
#  ('Israel', Decimal('422.01')),
#  ('Thailand', Decimal('419.04')),
#  ('Bangladesh', Decimal('402.05')),
#  ('Ecuador', Decimal('390.13')),
#  ('Algeria', Decimal('383.10')),
#  ('France', Decimal('374.04')),
#  ('Malaysia', Decimal('369.15')),
#  ('Mozambique', Decimal('344.20')),
#  ('Tanzania', Decimal('341.17')),
#  ('United Arab Emirates', Decimal('333.16')),
#  ('Chile', Decimal('328.29')),
#  ('Dominican Republic', Decimal('318.23')),
#  ('Morocco', Decimal('307.29')),
#  ('Austria', Decimal('307.22')),
#  ('Belarus', Decimal('277.34')),
#  ('Paraguay', Decimal('275.38')),
#  ('Latvia', Decimal('262.40')),
#  ('Yugoslavia', Decimal('259.43')),
#  ('Puerto Rico', Decimal('254.39')),
#  ('Kenya', Decimal('253.46')),
#  ('Switzerland', Decimal('252.39')),
#  ('Azerbaijan', Decimal('245.43')),
#  ('French Polynesia', Decimal('235.46')),
#  ('Romania', Decimal('235.38')),
#  ('Greece', Decimal('232.46')),
#  ('Sudan', Decimal('227.46')),
#  ('Runion', Decimal('216.54')),
#  ('Angola', Decimal('215.48')),
#  ('Congo, The Democratic Republic of the', Decimal('212.50')),
#  ('Bulgaria', Decimal('204.50')),
#  ('Cameroon', Decimal('200.46')),
#  ('Kazakstan', Decimal('198.48')),
#  ('Myanmar', Decimal('194.48')),
#  ('Cambodia', Decimal('191.47')),
#  ('Oman', Decimal('187.50')),
#  ('Bolivia', Decimal('183.53')),
#  ('Holy See (Vatican City State)', Decimal('152.66')),
#  ('Nauru', Decimal('148.69')),
#  ('Sweden', Decimal('144.66')),
#  ('Hong Kong', Decimal('142.70')),
#  ('Greenland', Decimal('137.66')),
#  ('Turkmenistan', Decimal('136.73')),
#  ('Chad', Decimal('135.68')),
#  ('Zambia', Decimal('134.67')),
#  ('Czech Republic', Decimal('133.71')),
#  ('Gambia', Decimal('129.70')),
#  ('Moldova', Decimal('127.66')),
#  ('Malawi', Decimal('123.72')),
#  ('Virgin Islands, U.S.', Decimal('122.68')),
#  ('Tuvalu', Decimal('120.74')),
#  ('Armenia', Decimal('118.75')),
#  ('Nepal', Decimal('116.78')),
#  ('Sri Lanka', Decimal('116.70')),
#  ('Estonia', Decimal('115.70')),
#  ('Liechtenstein', Decimal('114.72')),
#  ('Faroe Islands', Decimal('114.72')),
#  ('North Korea', Decimal('113.69')),
#  ('Brunei', Decimal('113.65')),
#  ('Bahrain', Decimal('112.75')),
#  ('Kuwait', Decimal('111.74')),
#  ('Iraq', Decimal('111.73')),
#  ('Hungary', Decimal('111.71')),
#  ('Anguilla', Decimal('106.65')),
#  ('French Guiana', Decimal('103.78')),
#  ('Finland', Decimal('101.74')),
#  ('Senegal', Decimal('100.75')),
#  ('Saint Vincent and the Grenadines', Decimal('96.75')),
#  ('Madagascar', Decimal('93.78')),
#  ('New Zealand', Decimal('92.76')),
#  ('Ethiopia', Decimal('91.77')),
#  ('Slovakia', Decimal('89.74')),
#  ('Tunisia', Decimal('78.77')),
#  ('Tonga', Decimal('73.82')),
#  ('Lithuania', Decimal('73.76')),
#  ('American Samoa', Decimal('71.80')),
#  ('Afghanistan', Decimal('67.82'))]

# %% [markdown]
# ## Revenue by Month
# TODO: Write a query that calculates total revenue (sales_amount) by month

# %%
# %%sql
# SELECT d.month, sum(s.sales_amount) AS revenue
# FROM factsales s
# JOIN dimdate d ON (s.date_key = d.date_key)
# GROUP BY month
# ORDER BY revenue desc;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 5 rows affected.
# [(4, Decimal('28559.46')),
#  (3, Decimal('23886.56')),
#  (2, Decimal('9631.88')),
#  (1, Decimal('4824.43')),
#  (5, Decimal('514.18'))]

# %% [markdown]
# ## Revenue by Month & Country
# TODO: Write a query that calculates total revenue (sales_amount) by month and country. Sort the data by month, country, and revenue in descending order. The first few rows of your output should match the table below.

# %%
# %%sql
# SELECT d.month, c.country, sum(s.sales_amount) AS revenue
# FROM factsales s
# JOIN dimdate d ON (s.date_key = d.date_key)
# JOIN dimcustomer c ON (s.customer_key = c.customer_key)
# GROUP BY (d.month, c.country, s.sales_amount)
# ORDER BY (d.month, c.country, s.sales_amount) DESC
# LIMIT 20;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 2768 rows affected.
# [(5, 'Zambia', Decimal('0.99')),
#  (5, 'Yemen', Decimal('2.99')),
#  (5, 'Vietnam', Decimal('4.99')),
#  (5, 'Vietnam', Decimal('2.99')),
#  (5, 'Vietnam', Decimal('0.99')),
#  (5, 'Venezuela', Decimal('5.98')),
#  (5, 'United States', Decimal('9.98')),
#  (5, 'United States', Decimal('7.96')),
#  (5, 'United States', Decimal('8.97')),
#  (5, 'United States', Decimal('1.98')),
#  (5, 'United States', Decimal('0.00')),
#  (5, 'United Kingdom', Decimal('9.98')),
#  (5, 'United Kingdom', Decimal('1.98')),
#  (5, 'United Arab Emirates', Decimal('4.99')),
#  (5, 'Turkmenistan', Decimal('2.99')),
#  (5, 'Turkey', Decimal('4.99')),
#  (5, 'Turkey', Decimal('5.98')),
#  (5, 'Tunisia', Decimal('0.99')),
#  (5, 'Thailand', Decimal('5.98')),
#  (5, 'Thailand', Decimal('0.00')),
#  (5, 'Tanzania', Decimal('4.99')),
#  (5, 'Taiwan', Decimal('8.97')),
#  (5, 'Taiwan', Decimal('5.98')),
#  (5, 'Taiwan', Decimal('2.99')),
#  (5, 'Taiwan', Decimal('0.99')),
#  (5, 'Taiwan', Decimal('0.00')),
#  (5, 'Switzerland', Decimal('7.98')),
#  (5, 'Switzerland', Decimal('0.00')),
#  (5, 'Spain', Decimal('9.98')),
#  (5, 'South Korea', Decimal('2.99')),
#  (5, 'South Korea', Decimal('0.99')),
#  (5, 'South Africa', Decimal('4.99')),
#  (5, 'Saudi Arabia', Decimal('2.99')),
#  (5, 'Saudi Arabia', Decimal('0.99')),
#  (5, 'Russian Federation', Decimal('4.99')),
#  (5, 'Russian Federation', Decimal('2.97')),
#  (5, 'Puerto Rico', Decimal('0.99')),
#  (5, 'Philippines', Decimal('14.97')),
#  (5, 'Philippines', Decimal('5.98')),
#  (5, 'Philippines', Decimal('4.95')),
#  (5, 'Peru', Decimal('4.99')),
#  (5, 'Oman', Decimal('4.99')),
#  (5, 'Nigeria', Decimal('5.98')),
#  (5, 'Nigeria', Decimal('2.99')),
#  (5, 'Nigeria', Decimal('0.00')),
#  (5, 'Netherlands', Decimal('0.99')),
#  (5, 'Morocco', Decimal('4.99')),
#  (5, 'Mexico', Decimal('4.99')),
#  (5, 'Mexico', Decimal('5.98')),
#  (5, 'Mexico', Decimal('2.97')),
#  (5, 'Malaysia', Decimal('0.99')),
#  (5, 'Lithuania', Decimal('4.99')),
#  (5, 'Latvia', Decimal('2.99')),
#  (5, 'Kuwait', Decimal('0.99')),
#  (5, 'Kenya', Decimal('2.99')),
#  (5, 'Japan', Decimal('15.96')),
#  (5, 'Japan', Decimal('2.99')),
#  (5, 'Japan', Decimal('3.96')),
#  (5, 'Japan', Decimal('0.00')),
#  (5, 'Italy', Decimal('2.99')),
#  (5, 'Italy', Decimal('0.99')),
#  (5, 'Israel', Decimal('2.99')),
#  (5, 'Iraq', Decimal('0.99')),
#  (5, 'Iran', Decimal('4.99')),
#  (5, 'Indonesia', Decimal('4.99')),
#  (5, 'Indonesia', Decimal('0.99')),
#  (5, 'India', Decimal('9.98')),
#  (5, 'India', Decimal('5.98')),
#  (5, 'India', Decimal('19.96')),
#  (5, 'India', Decimal('7.96')),
#  (5, 'India', Decimal('11.96')),
#  (5, 'India', Decimal('6.93')),
#  (5, 'India', Decimal('0.00')),
#  (5, 'Hungary', Decimal('0.99')),
#  (5, 'Greece', Decimal('0.99')),
#  (5, 'Germany', Decimal('9.98')),
#  (5, 'Germany', Decimal('3.98')),
#  (5, 'Germany', Decimal('0.99')),
#  (5, 'Germany', Decimal('0.00')),
#  (5, 'French Polynesia', Decimal('4.99')),
#  (5, 'French Polynesia', Decimal('3.98')),
#  (5, 'French Polynesia', Decimal('0.00')),
#  (5, 'France', Decimal('0.99')),
#  (5, 'Faroe Islands', Decimal('0.99')),
#  (5, 'Colombia', Decimal('14.97')),
#  (5, 'China', Decimal('7.98')),
#  (5, 'China', Decimal('14.97')),
#  (5, 'China', Decimal('14.95')),
#  (5, 'China', Decimal('2.97')),
#  (5, 'China', Decimal('0.00')),
#  (5, 'Canada', Decimal('2.99')),
#  (5, 'Canada', Decimal('0.99')),
#  (5, 'Cameroon', Decimal('3.98')),
#  (5, 'Cameroon', Decimal('2.99')),
#  (5, 'Cameroon', Decimal('0.00')),
#  (5, 'Cambodia', Decimal('5.98')),
#  (5, 'Cambodia', Decimal('3.98')),
#  (5, 'Cambodia', Decimal('0.00')),
#  (5, 'Bulgaria', Decimal('0.99')),
#  (5, 'Brunei', Decimal('4.99')),
#  (5, 'Brazil', Decimal('7.98')),
#  (5, 'Brazil', Decimal('5.98')),
#  (5, 'Brazil', Decimal('4.99')),
#  (5, 'Brazil', Decimal('2.99')),
#  (5, 'Brazil', Decimal('0.99')),
#  (5, 'Brazil', Decimal('0.00')),
#  (5, 'Bolivia', Decimal('2.99')),
#  (5, 'Belarus', Decimal('2.99')),
#  (5, 'Bangladesh', Decimal('2.99')),
#  (5, 'Bahrain', Decimal('2.99')),
#  (5, 'Azerbaijan', Decimal('0.99')),
#  (5, 'Armenia', Decimal('2.99')),
#  (5, 'Argentina', Decimal('5.98')),
#  (5, 'Argentina', Decimal('14.97')),
#  (5, 'Argentina', Decimal('2.99')),
#  (5, 'Argentina', Decimal('1.98')),
#  (5, 'Argentina', Decimal('0.99')),
#  (5, 'Argentina', Decimal('0.00')),
#  (5, 'Algeria', Decimal('4.99')),
#  (5, 'Algeria', Decimal('0.99')),
#  (4, 'Zambia', Decimal('8.99')),
#  (4, 'Zambia', Decimal('24.95')),
#  (4, 'Zambia', Decimal('7.98')),
#  (4, 'Zambia', Decimal('8.97')),
#  (4, 'Zambia', Decimal('1.99')),
#  (4, 'Zambia', Decimal('1.98')),
#  (4, 'Yugoslavia', Decimal('8.99')),
#  (4, 'Yugoslavia', Decimal('15.98')),
#  (4, 'Yugoslavia', Decimal('13.98')),
#  (4, 'Yugoslavia', Decimal('17.97')),
#  (4, 'Yugoslavia', Decimal('44.91')),
#  (4, 'Yugoslavia', Decimal('7.98')),
#  (4, 'Yugoslavia', Decimal('14.95')),
#  (4, 'Yugoslavia', Decimal('1.99')),
#  (4, 'Yugoslavia', Decimal('1.98')),
#  (4, 'Yemen', Decimal('10.99')),
#  (4, 'Yemen', Decimal('26.97')),
#  (4, 'Yemen', Decimal('7.99')),
#  (4, 'Yemen', Decimal('34.95')),
#  (4, 'Yemen', Decimal('29.95')),
#  (4, 'Yemen', Decimal('104.79')),
#  (4, 'Yemen', Decimal('11.97')),
#  (4, 'Yemen', Decimal('23.92')),
#  (4, 'Yemen', Decimal('1.99')),
#  (4, 'Yemen', Decimal('8.91')),
#  (4, 'Virgin Islands, U.S.', Decimal('8.99')),
#  (4, 'Virgin Islands, U.S.', Decimal('7.99')),
#  (4, 'Virgin Islands, U.S.', Decimal('5.99')),
#  (4, 'Virgin Islands, U.S.', Decimal('29.94')),
#  (4, 'Virgin Islands, U.S.', Decimal('8.97')),
#  (4, 'Virgin Islands, U.S.', Decimal('1.99')),
#  (4, 'Virgin Islands, U.S.', Decimal('4.95')),
#  (4, 'Vietnam', Decimal('10.99')),
#  (4, 'Vietnam', Decimal('17.98')),
#  (4, 'Vietnam', Decimal('23.97')),
#  (4, 'Vietnam', Decimal('34.95')),
#  (4, 'Vietnam', Decimal('41.93')),
#  (4, 'Vietnam', Decimal('89.82')),
#  (4, 'Vietnam', Decimal('11.97')),
#  (4, 'Vietnam', Decimal('68.77')),
#  (4, 'Vietnam', Decimal('1.99')),
#  (4, 'Vietnam', Decimal('5.94')),
#  (4, 'Venezuela', Decimal('9.99')),
#  (4, 'Venezuela', Decimal('8.99')),
#  (4, 'Venezuela', Decimal('31.96')),
#  (4, 'Venezuela', Decimal('41.94')),
#  (4, 'Venezuela', Decimal('35.94')),
#  (4, 'Venezuela', Decimal('79.84')),
#  (4, 'Venezuela', Decimal('7.98')),
#  (4, 'Venezuela', Decimal('50.83')),
#  (4, 'Venezuela', Decimal('9.95')),
#  (4, 'Venezuela', Decimal('14.85')),
#  (4, 'United States', Decimal('43.96')),
#  (4, 'United States', Decimal('79.92')),
#  (4, 'United States', Decimal('107.88')),
#  (4, 'United States', Decimal('143.82')),
#  (4, 'United States', Decimal('202.71')),
#  (4, 'United States', Decimal('209.65')),
#  (4, 'United States', Decimal('444.11')),
#  (4, 'United States', Decimal('87.78')),
#  (4, 'United States', Decimal('251.16')),
#  (4, 'United States', Decimal('25.87')),
#  (4, 'United States', Decimal('65.34')),
#  (4, 'United Kingdom', Decimal('10.99')),
#  (4, 'United Kingdom', Decimal('19.98')),
#  (4, 'United Kingdom', Decimal('8.99')),
#  (4, 'United Kingdom', Decimal('55.93')),
#  (4, 'United Kingdom', Decimal('41.94')),
#  (4, 'United Kingdom', Decimal('59.90')),
#  (4, 'United Kingdom', Decimal('84.83')),
#  (4, 'United Kingdom', Decimal('11.97')),
#  (4, 'United Kingdom', Decimal('62.79')),
#  (4, 'United Kingdom', Decimal('1.99')),
#  (4, 'United Kingdom', Decimal('20.79')),
#  (4, 'United Arab Emirates', Decimal('17.98')),
#  (4, 'United Arab Emirates', Decimal('7.99')),
#  (4, 'United Arab Emirates', Decimal('27.96')),
#  (4, 'United Arab Emirates', Decimal('23.96')),
#  (4, 'United Arab Emirates', Decimal('39.92')),
#  (4, 'United Arab Emirates', Decimal('7.98')),
#  (4, 'United Arab Emirates', Decimal('23.92')),
#  (4, 'United Arab Emirates', Decimal('5.97')),
#  (4, 'United Arab Emirates', Decimal('5.94')),
#  (4, 'Ukraine', Decimal('10.99')),
#  (4, 'Ukraine', Decimal('19.98')),
#  (4, 'Ukraine', Decimal('44.95')),
#  (4, 'Ukraine', Decimal('31.96')),
#  (4, 'Ukraine', Decimal('55.92')),
#  (4, 'Ukraine', Decimal('35.94')),
#  (4, 'Ukraine', Decimal('59.88')),
#  (4, 'Ukraine', Decimal('27.93')),
#  (4, 'Ukraine', Decimal('50.83')),
#  (4, 'Ukraine', Decimal('1.99')),
#  (4, 'Ukraine', Decimal('7.92')),
#  (4, 'Tuvalu', Decimal('9.99')),
#  (4, 'Tuvalu', Decimal('5.99')),
#  (4, 'Tuvalu', Decimal('19.96')),
#  (4, 'Tuvalu', Decimal('3.99')),
#  (4, 'Tuvalu', Decimal('8.97')),
#  (4, 'Turkmenistan', Decimal('6.99')),
#  (4, 'Turkmenistan', Decimal('9.98')),
#  (4, 'Turkmenistan', Decimal('7.98')),
#  (4, 'Turkmenistan', Decimal('11.96')),
#  (4, 'Turkmenistan', Decimal('0.99')),
#  (4, 'Turkey', Decimal('11.99')),
#  (4, 'Turkey', Decimal('39.96')),
#  (4, 'Turkey', Decimal('26.97')),
#  (4, 'Turkey', Decimal('79.90')),
#  (4, 'Turkey', Decimal('118.83')),
#  (4, 'Turkey', Decimal('59.90')),
#  (4, 'Turkey', Decimal('189.62')),
#  (4, 'Turkey', Decimal('35.91')),
#  (4, 'Turkey', Decimal('137.54')),
#  (4, 'Turkey', Decimal('13.93')),
#  (4, 'Turkey', Decimal('27.72')),
#  (4, 'Tunisia', Decimal('8.99')),
#  (4, 'Tunisia', Decimal('7.99')),
#  (4, 'Tunisia', Decimal('5.99')),
#  (4, 'Tunisia', Decimal('14.97')),
#  (4, 'Tunisia', Decimal('3.99')),
#  (4, 'Tunisia', Decimal('8.97')),
#  (4, 'Tunisia', Decimal('4.95')),
#  (4, 'Tonga', Decimal('11.98')),
#  (4, 'Tonga', Decimal('9.98')),
#  (4, 'Tonga', Decimal('3.99')),
#  (4, 'Tonga', Decimal('2.99')),
#  (4, 'Thailand', Decimal('10.99')),
#  (4, 'Thailand', Decimal('9.99')),
#  (4, 'Thailand', Decimal('8.99')),
#  (4, 'Thailand', Decimal('7.99')),
#  (4, 'Thailand', Decimal('13.98')),
#  (4, 'Thailand', Decimal('29.95')),
#  (4, 'Thailand', Decimal('34.93')),
#  (4, 'Thailand', Decimal('27.93')),
#  (4, 'Thailand', Decimal('32.89')),
#  (4, 'Thailand', Decimal('5.94')),
#  (4, 'Tanzania', Decimal('21.98')),
#  (4, 'Tanzania', Decimal('9.99')),
#  (4, 'Tanzania', Decimal('8.99')),
#  (4, 'Tanzania', Decimal('15.98')),
#  (4, 'Tanzania', Decimal('13.98')),
#  (4, 'Tanzania', Decimal('11.98')),
#  (4, 'Tanzania', Decimal('19.96')),
#  (4, 'Tanzania', Decimal('7.98')),
#  (4, 'Tanzania', Decimal('26.91')),
#  (4, 'Tanzania', Decimal('1.99')),
#  (4, 'Tanzania', Decimal('5.94')),
#  (4, 'Taiwan', Decimal('39.96')),
#  (4, 'Taiwan', Decimal('35.96')),
#  (4, 'Taiwan', Decimal('31.96')),
#  (4, 'Taiwan', Decimal('55.92')),
#  (4, 'Taiwan', Decimal('53.91')),
#  (4, 'Taiwan', Decimal('179.64')),
#  (4, 'Taiwan', Decimal('27.93')),
#  (4, 'Taiwan', Decimal('107.64')),
#  (4, 'Taiwan', Decimal('7.96')),
#  (4, 'Taiwan', Decimal('24.75')),
#  (4, 'Switzerland', Decimal('15.98')),
#  (4, 'Switzerland', Decimal('27.96')),
#  (4, 'Switzerland', Decimal('23.96')),
#  (4, 'Switzerland', Decimal('44.91')),
#  (4, 'Switzerland', Decimal('11.97')),
#  (4, 'Switzerland', Decimal('5.98')),
#  (4, 'Switzerland', Decimal('3.98')),
#  (4, 'Switzerland', Decimal('5.94')),
#  (4, 'Sweden', Decimal('8.99')),
#  (4, 'Sweden', Decimal('6.99')),
#  (4, 'Sweden', Decimal('17.97')),
#  (4, 'Sweden', Decimal('9.98')),
#  (4, 'Sweden', Decimal('3.99')),
#  (4, 'Sweden', Decimal('11.96')),
#  (4, 'Sweden', Decimal('0.99')),
#  (4, 'Sudan', Decimal('10.99')),
#  (4, 'Sudan', Decimal('9.99')),
#  (4, 'Sudan', Decimal('8.99')),
#  (4, 'Sudan', Decimal('7.99')),
#  (4, 'Sudan', Decimal('13.98')),
#  (4, 'Sudan', Decimal('11.98')),
#  (4, 'Sudan', Decimal('24.95')),
#  (4, 'Sudan', Decimal('8.97')),
#  (4, 'Sudan', Decimal('7.92')),
#  (4, 'Sri Lanka', Decimal('6.99')),
#  (4, 'Sri Lanka', Decimal('24.95')),
#  (4, 'Sri Lanka', Decimal('7.98')),
#  (4, 'Sri Lanka', Decimal('2.99')),
#  (4, 'Sri Lanka', Decimal('2.97')),
#  (4, 'Spain', Decimal('10.99')),
#  (4, 'Spain', Decimal('19.98')),
#  (4, 'Spain', Decimal('23.97')),
#  (4, 'Spain', Decimal('41.94')),
#  (4, 'Spain', Decimal('5.99')),
#  (4, 'Spain', Decimal('89.82')),
#  (4, 'Spain', Decimal('31.92')),
#  (4, 'Spain', Decimal('17.94')),
#  (4, 'Spain', Decimal('1.99')),
#  (4, 'Spain', Decimal('12.87')),
#  (4, 'South Korea', Decimal('10.99')),
#  (4, 'South Korea', Decimal('26.97')),
#  (4, 'South Korea', Decimal('7.99')),
#  (4, 'South Korea', Decimal('27.96')),
#  (4, 'South Korea', Decimal('41.93')),
#  (4, 'South Korea', Decimal('89.82')),
#  (4, 'South Korea', Decimal('19.95')),
#  (4, 'South Korea', Decimal('50.83')),
#  (4, 'South Korea', Decimal('3.98')),
#  (4, 'South Korea', Decimal('10.89')),
#  (4, 'South Africa', Decimal('39.96')),
#  (4, 'South Africa', Decimal('17.98')),
#  (4, 'South Africa', Decimal('47.94')),
#  (4, 'South Africa', Decimal('55.92')),
#  (4, 'South Africa', Decimal('53.91')),
#  (4, 'South Africa', Decimal('119.76')),
#  (4, 'South Africa', Decimal('11.97')),
#  (4, 'South Africa', Decimal('83.72')),
#  (4, 'South Africa', Decimal('9.95')),
#  (4, 'South Africa', Decimal('26.73')),
#  (4, 'Slovakia', Decimal('8.99')),
#  (4, 'Slovakia', Decimal('5.99')),
#  (4, 'Slovakia', Decimal('4.99')),
#  (4, 'Slovakia', Decimal('7.98')),
#  (4, 'Slovakia', Decimal('11.96')),
#  (4, 'Slovakia', Decimal('2.97')),
#  (4, 'Senegal', Decimal('7.99')),
#  (4, 'Senegal', Decimal('4.99')),
#  (4, 'Senegal', Decimal('3.99')),
#  (4, 'Senegal', Decimal('5.98')),
#  (4, 'Senegal', Decimal('1.98')),
#  (4, 'Saudi Arabia', Decimal('10.99')),
#  (4, 'Saudi Arabia', Decimal('9.99')),
#  (4, 'Saudi Arabia', Decimal('17.98')),
#  (4, 'Saudi Arabia', Decimal('15.98')),
#  (4, 'Saudi Arabia', Decimal('34.95')),
#  (4, 'Saudi Arabia', Decimal('29.95')),
#  (4, 'Saudi Arabia', Decimal('59.88')),
#  (4, 'Saudi Arabia', Decimal('7.98')),
#  (4, 'Saudi Arabia', Decimal('38.87')),
#  (4, 'Saudi Arabia', Decimal('3.98')),
#  (4, 'Saudi Arabia', Decimal('5.94')),
#  (4, 'Saint Vincent and the Grenadines', Decimal('7.99')),
#  (4, 'Saint Vincent and the Grenadines', Decimal('11.98')),
#  (4, 'Saint Vincent and the Grenadines', Decimal('14.97')),
#  (4, 'Saint Vincent and the Grenadines', Decimal('8.97')),
#  (4, 'Saint Vincent and the Grenadines', Decimal('2.97')),
#  (4, 'Russian Federation', Decimal('39.96')),
#  (4, 'Russian Federation', Decimal('206.77')),
#  (4, 'Russian Federation', Decimal('103.87')),
#  (4, 'Russian Federation', Decimal('223.68')),
#  (4, 'Russian Federation', Decimal('143.76')),
#  (4, 'Russian Federation', Decimal('359.28')),
#  (4, 'Russian Federation', Decimal('87.78')),
#  (4, 'Russian Federation', Decimal('188.37')),
#  (4, 'Russian Federation', Decimal('31.84')),
#  (4, 'Russian Federation', Decimal('41.58')),
#  (4, 'Runion', Decimal('10.99')),
#  (4, 'Runion', Decimal('9.99')),
#  (4, 'Runion', Decimal('8.99')),
#  (4, 'Runion', Decimal('5.99')),
#  (4, 'Runion', Decimal('44.91')),
#  (4, 'Runion', Decimal('3.99')),
#  (4, 'Runion', Decimal('8.97')),
#  (4, 'Runion', Decimal('3.98')),
#  (4, 'Runion', Decimal('2.97')),
#  (4, 'Romania', Decimal('9.99')),
#  (4, 'Romania', Decimal('7.99')),
#  (4, 'Romania', Decimal('13.98')),
#  (4, 'Romania', Decimal('11.98')),
#  (4, 'Romania', Decimal('29.94')),
#  (4, 'Romania', Decimal('19.95')),
#  (4, 'Romania', Decimal('14.95')),
#  (4, 'Romania', Decimal('3.98')),
#  (4, 'Romania', Decimal('6.93')),
#  (4, 'Puerto Rico', Decimal('19.98')),
#  (4, 'Puerto Rico', Decimal('8.99')),
#  (4, 'Puerto Rico', Decimal('7.99')),
#  (4, 'Puerto Rico', Decimal('13.98')),
#  (4, 'Puerto Rico', Decimal('5.99')),
#  (4, 'Puerto Rico', Decimal('24.95')),
#  (4, 'Puerto Rico', Decimal('15.96')),
#  (4, 'Puerto Rico', Decimal('26.91')),
#  (4, 'Puerto Rico', Decimal('5.97')),
#  (4, 'Puerto Rico', Decimal('3.96')),
#  (4, 'Poland', Decimal('10.99')),
#  (4, 'Poland', Decimal('29.97')),
#  (4, 'Poland', Decimal('35.96')),
#  (4, 'Poland', Decimal('15.98')),
#  (4, 'Poland', Decimal('48.93')),
#  (4, 'Poland', Decimal('41.93')),
#  (4, 'Poland', Decimal('84.83')),
#  (4, 'Poland', Decimal('31.92')),
#  (4, 'Poland', Decimal('71.76')),
#  (4, 'Poland', Decimal('3.98')),
#  (4, 'Poland', Decimal('12.87')),
#  (4, 'Philippines', Decimal('10.99')),
#  (4, 'Philippines', Decimal('19.98')),
#  (4, 'Philippines', Decimal('53.94')),
#  (4, 'Philippines', Decimal('39.95')),
#  (4, 'Philippines', Decimal('62.91')),
#  (4, 'Philippines', Decimal('131.78')),
#  (4, 'Philippines', Decimal('344.31')),
#  (4, 'Philippines', Decimal('63.84')),
#  (4, 'Philippines', Decimal('125.58')),
#  (4, 'Philippines', Decimal('25.87')),
#  (4, 'Philippines', Decimal('49.50')),
#  (4, 'Peru', Decimal('8.99')),
#  (4, 'Peru', Decimal('15.98')),
#  (4, 'Peru', Decimal('20.97')),
#  (4, 'Peru', Decimal('17.97')),
#  (4, 'Peru', Decimal('64.87')),
#  (4, 'Peru', Decimal('3.99')),
#  (4, 'Peru', Decimal('32.89')),
#  (4, 'Peru', Decimal('11.88')),
#  (4, 'Paraguay', Decimal('9.99')),
#  (4, 'Paraguay', Decimal('17.98')),
#  (4, 'Paraguay', Decimal('31.96')),
#  (4, 'Paraguay', Decimal('6.99')),
#  (4, 'Paraguay', Decimal('5.99')),
#  (4, 'Paraguay', Decimal('34.93')),
#  (4, 'Paraguay', Decimal('11.97')),
#  (4, 'Paraguay', Decimal('26.91')),
#  (4, 'Pakistan', Decimal('8.99')),
#  (4, 'Pakistan', Decimal('15.98')),
#  (4, 'Pakistan', Decimal('13.98')),
#  (4, 'Pakistan', Decimal('29.95')),
#  (4, 'Pakistan', Decimal('29.94')),
#  (4, 'Pakistan', Decimal('15.96')),
#  (4, 'Pakistan', Decimal('62.79')),
#  (4, 'Pakistan', Decimal('5.94')),
#  (4, 'Oman', Decimal('6.99')),
#  (4, 'Oman', Decimal('5.99')),
#  (4, 'Oman', Decimal('34.93')),
#  (4, 'Oman', Decimal('23.92')),
#  (4, 'Oman', Decimal('3.98')),
#  (4, 'Oman', Decimal('4.95')),
#  (4, 'North Korea', Decimal('5.99')),
#  (4, 'North Korea', Decimal('29.94')),
#  (4, 'North Korea', Decimal('3.99')),
#  (4, 'North Korea', Decimal('11.96')),
#  (4, 'North Korea', Decimal('5.94')),
#  (4, 'Nigeria', Decimal('10.99')),
#  (4, 'Nigeria', Decimal('9.99')),
#  (4, 'Nigeria', Decimal('26.97')),
#  (4, 'Nigeria', Decimal('31.96')),
#  (4, 'Nigeria', Decimal('104.85')),
#  (4, 'Nigeria', Decimal('101.83')),
#  (4, 'Nigeria', Decimal('169.66')),
#  (4, 'Nigeria', Decimal('43.89')),
#  (4, 'Nigeria', Decimal('110.63')),
#  (4, 'Nigeria', Decimal('5.97')),
#  (4, 'Nigeria', Decimal('30.69')),
#  (4, 'New Zealand', Decimal('5.99')),
#  (4, 'New Zealand', Decimal('4.99')),
#  (4, 'New Zealand', Decimal('7.98')),
#  (4, 'New Zealand', Decimal('11.96')),
#  (4, 'New Zealand', Decimal('1.99')),
#  (4, 'New Zealand', Decimal('2.97')),
#  (4, 'Netherlands', Decimal('9.99')),
#  (4, 'Netherlands', Decimal('17.98')),
#  (4, 'Netherlands', Decimal('15.98')),
#  (4, 'Netherlands', Decimal('48.93')),
#  (4, 'Netherlands', Decimal('11.98')),
#  (4, 'Netherlands', Decimal('64.87')),
#  (4, 'Netherlands', Decimal('11.97')),
#  (4, 'Netherlands', Decimal('41.86')),
#  (4, 'Netherlands', Decimal('1.99')),
#  (4, 'Netherlands', Decimal('10.89')),
#  (4, 'Nepal', Decimal('8.99')),
#  (4, 'Nepal', Decimal('6.99')),
#  (4, 'Nepal', Decimal('17.97')),
#  (4, 'Nepal', Decimal('9.98')),
#  (4, 'Nepal', Decimal('5.98')),
#  (4, 'Nepal', Decimal('0.99')),
#  (4, 'Nauru', Decimal('9.99')),
#  (4, 'Nauru', Decimal('7.99')),
#  (4, 'Nauru', Decimal('5.99')),
#  (4, 'Nauru', Decimal('24.95')),
#  (4, 'Nauru', Decimal('3.99')),
#  (4, 'Nauru', Decimal('5.98')),
#  (4, 'Nauru', Decimal('1.98')),
#  (4, 'Myanmar', Decimal('11.98')),
#  (4, 'Myanmar', Decimal('7.98')),
#  (4, 'Myanmar', Decimal('11.96')),
#  (4, 'Myanmar', Decimal('2.97')),
#  (4, 'Mozambique', Decimal('8.99')),
#  (4, 'Mozambique', Decimal('7.99')),
#  (4, 'Mozambique', Decimal('27.96')),
#  (4, 'Mozambique', Decimal('35.94')),
#  (4, 'Mozambique', Decimal('79.84')),
#  (4, 'Mozambique', Decimal('7.98')),
#  (4, 'Mozambique', Decimal('17.94')),
#  (4, 'Mozambique', Decimal('1.99')),
#  (4, 'Mozambique', Decimal('6.93')),
#  (4, 'Morocco', Decimal('8.99')),
#  (4, 'Morocco', Decimal('7.99')),
#  (4, 'Morocco', Decimal('13.98')),
#  (4, 'Morocco', Decimal('5.99')),
#  (4, 'Morocco', Decimal('29.94')),
#  (4, 'Morocco', Decimal('3.99')),
#  (4, 'Morocco', Decimal('20.93')),
#  (4, 'Morocco', Decimal('3.98')),
#  (4, 'Morocco', Decimal('4.95')),
#  (4, 'Moldova', Decimal('23.96')),
#  (4, 'Moldova', Decimal('19.96')),
#  (4, 'Moldova', Decimal('3.99')),
#  (4, 'Moldova', Decimal('11.96')),
#  (4, 'Moldova', Decimal('1.99')),
#  (4, 'Moldova', Decimal('3.96')),
#  (4, 'Mexico', Decimal('21.98')),
#  (4, 'Mexico', Decimal('49.95')),
#  (4, 'Mexico', Decimal('125.86')),
#  (4, 'Mexico', Decimal('111.86')),
#  (4, 'Mexico', Decimal('174.75')),
#  (4, 'Mexico', Decimal('173.71')),
#  (4, 'Mexico', Decimal('349.30')),
#  (4, 'Mexico', Decimal('63.84')),
#  (4, 'Mexico', Decimal('236.21')),
#  (4, 'Mexico', Decimal('25.87')),
#  (4, 'Mexico', Decimal('53.46')),
#  (4, 'Malaysia', Decimal('9.99')),
#  (4, 'Malaysia', Decimal('20.97')),
#  (4, 'Malaysia', Decimal('17.97')),
#  (4, 'Malaysia', Decimal('49.90')),
#  (4, 'Malaysia', Decimal('3.99')),
#  (4, 'Malaysia', Decimal('20.93')),
#  (4, 'Malaysia', Decimal('3.98')),
#  (4, 'Malaysia', Decimal('5.94')),
#  (4, 'Malawi', Decimal('8.99')),
#  (4, 'Malawi', Decimal('7.99')),
#  (4, 'Malawi', Decimal('6.99')),
#  (4, 'Malawi', Decimal('5.99')),
#  (4, 'Malawi', Decimal('9.98')),
#  (4, 'Malawi', Decimal('14.95')),
#  (4, 'Malawi', Decimal('1.98')),
#  (4, 'Madagascar', Decimal('9.99')),
#  (4, 'Madagascar', Decimal('4.99')),
#  (4, 'Madagascar', Decimal('3.99')),
#  (4, 'Madagascar', Decimal('2.99')),
#  (4, 'Madagascar', Decimal('1.98')),
#  (4, 'Lithuania', Decimal('6.99')),
#  (4, 'Lithuania', Decimal('4.99')),
#  (4, 'Lithuania', Decimal('3.99')),
#  (4, 'Lithuania', Decimal('2.99')),
#  (4, 'Lithuania', Decimal('3.98')),
#  (4, 'Lithuania', Decimal('3.96')),
#  (4, 'Liechtenstein', Decimal('5.99')),
#  (4, 'Liechtenstein', Decimal('29.94')),
#  (4, 'Liechtenstein', Decimal('5.98')),
#  (4, 'Liechtenstein', Decimal('3.98')),
#  (4, 'Liechtenstein', Decimal('3.96')),
#  (4, 'Latvia', Decimal('9.99')),
#  (4, 'Latvia', Decimal('7.99')),
#  (4, 'Latvia', Decimal('13.98')),
#  (4, 'Latvia', Decimal('17.97')),
#  (4, 'Latvia', Decimal('34.93')),
#  (4, 'Latvia', Decimal('11.97')),
#  (4, 'Latvia', Decimal('23.92')),
#  (4, 'Latvia', Decimal('1.99')),
#  (4, 'Latvia', Decimal('3.96')),
#  (4, 'Kuwait', Decimal('7.99')),
#  (4, 'Kuwait', Decimal('5.99')),
#  (4, 'Kuwait', Decimal('0.99')),
#  (4, 'Kenya', Decimal('8.99')),
#  (4, 'Kenya', Decimal('13.98')),
#  (4, 'Kenya', Decimal('44.91')),
#  (4, 'Kenya', Decimal('11.97')),
#  (4, 'Kenya', Decimal('17.94')),
#  (4, 'Kazakstan', Decimal('10.99')),
#  (4, 'Kazakstan', Decimal('9.99')),
#  (4, 'Kazakstan', Decimal('7.99')),
#  (4, 'Kazakstan', Decimal('6.99')),
#  (4, 'Kazakstan', Decimal('11.98')),
#  (4, 'Kazakstan', Decimal('19.96')),
#  (4, 'Kazakstan', Decimal('3.99')),
#  (4, 'Kazakstan', Decimal('17.94')),
#  (4, 'Kazakstan', Decimal('6.93')),
#  (4, 'Japan', Decimal('21.98')),
#  (4, 'Japan', Decimal('59.94')),
#  (4, 'Japan', Decimal('62.93')),
#  (4, 'Japan', Decimal('159.80')),
#  (4, 'Japan', Decimal('160.77')),
#  (4, 'Japan', Decimal('137.77')),
#  (4, 'Japan', Decimal('424.15')),
#  (4, 'Japan', Decimal('71.82')),
#  (4, 'Japan', Decimal('227.24')),
#  (4, 'Japan', Decimal('29.85')),
#  (4, 'Japan', Decimal('62.37')),
#  (4, 'Italy', Decimal('26.97')),
#  (4, 'Italy', Decimal('31.96')),
#  (4, 'Italy', Decimal('41.94')),
#  (4, 'Italy', Decimal('47.92')),
#  (4, 'Italy', Decimal('114.77')),
#  (4, 'Italy', Decimal('7.98')),
#  (4, 'Italy', Decimal('50.83')),
#  (4, 'Italy', Decimal('3.98')),
#  (4, 'Italy', Decimal('12.87')),
#  (4, 'Israel', Decimal('9.99')),
#  (4, 'Israel', Decimal('48.93')),
#  (4, 'Israel', Decimal('29.95')),
#  (4, 'Israel', Decimal('74.85')),
#  (4, 'Israel', Decimal('7.98')),
#  (4, 'Israel', Decimal('20.93')),
#  (4, 'Israel', Decimal('3.98')),
#  (4, 'Israel', Decimal('6.93')),
#  (4, 'Iraq', Decimal('19.98')),
#  (4, 'Iraq', Decimal('8.99')),
#  (4, 'Iraq', Decimal('6.99')),
#  (4, 'Iraq', Decimal('5.99')),
#  (4, 'Iraq', Decimal('9.98')),
#  (4, 'Iraq', Decimal('8.97')),
#  (4, 'Iraq', Decimal('1.99')),
#  (4, 'Iraq', Decimal('2.97')),
#  (4, 'Iran', Decimal('21.98')),
#  (4, 'Iran', Decimal('29.97')),
#  (4, 'Iran', Decimal('35.96')),
#  (4, 'Iran', Decimal('31.96')),
#  (4, 'Iran', Decimal('55.92')),
#  (4, 'Iran', Decimal('29.95')),
#  (4, 'Iran', Decimal('84.83')),
#  (4, 'Iran', Decimal('27.93')),
#  (4, 'Iran', Decimal('65.78')),
#  (4, 'Iran', Decimal('5.97')),
#  (4, 'Iran', Decimal('19.80')),
#  (4, 'Indonesia', Decimal('10.99')),
#  (4, 'Indonesia', Decimal('29.97')),
#  (4, 'Indonesia', Decimal('53.94')),
#  (4, 'Indonesia', Decimal('71.91')),
#  (4, 'Indonesia', Decimal('76.89')),
#  (4, 'Indonesia', Decimal('89.85')),
#  (4, 'Indonesia', Decimal('129.74')),
#  (4, 'Indonesia', Decimal('31.92')),
#  (4, 'Indonesia', Decimal('71.76')),
#  (4, 'Indonesia', Decimal('7.96')),
#  (4, 'Indonesia', Decimal('31.68')),
#  (4, 'India', Decimal('32.97')),
#  (4, 'India', Decimal('89.91')),
#  (4, 'India', Decimal('179.80')),
#  (4, 'India', Decimal('263.67')),
#  (4, 'India', Decimal('286.59')),
#  (4, 'India', Decimal('359.40')),
#  (4, 'India', Decimal('768.46')),
#  (4, 'India', Decimal('195.51')),
#  (4, 'India', Decimal('418.60')),
#  (4, 'India', Decimal('37.81')),
#  (4, 'India', Decimal('124.74')),
#  (4, 'Hungary', Decimal('11.99')),
#  (4, 'Hungary', Decimal('9.99')),
#  (4, 'Hungary', Decimal('6.99')),
#  (4, 'Hungary', Decimal('9.98')),
#  (4, 'Hungary', Decimal('7.98')),
#  (4, 'Hungary', Decimal('8.97')),
#  (4, 'Hungary', Decimal('1.99')),
#  (4, 'Hungary', Decimal('3.96')),
#  (4, 'Hong Kong', Decimal('8.99')),
#  (4, 'Hong Kong', Decimal('7.99')),
#  (4, 'Hong Kong', Decimal('19.96')),
#  (4, 'Hong Kong', Decimal('3.99')),
#  (4, 'Hong Kong', Decimal('5.98')),
#  (4, 'Hong Kong', Decimal('2.97')),
#  (4, 'Holy See (Vatican City State)', Decimal('13.98')),
#  (4, 'Holy See (Vatican City State)', Decimal('14.97')),
#  (4, 'Holy See (Vatican City State)', Decimal('3.99')),
#  (4, 'Holy See (Vatican City State)', Decimal('8.97')),
#  (4, 'Holy See (Vatican City State)', Decimal('1.99')),
#  (4, 'Holy See (Vatican City State)', Decimal('2.97')),
#  (4, 'Greenland', Decimal('9.99')),
#  (4, 'Greenland', Decimal('29.95')),
#  (4, 'Greenland', Decimal('4.99')),
#  (4, 'Greenland', Decimal('8.97')),
#  (4, 'Greenland', Decimal('4.95')),
#  (4, 'Greece', Decimal('10.99')),
#  (4, 'Greece', Decimal('7.99')),
#  (4, 'Greece', Decimal('6.99')),
#  (4, 'Greece', Decimal('5.99')),
#  (4, 'Greece', Decimal('34.93')),
#  (4, 'Greece', Decimal('11.97')),
#  (4, 'Greece', Decimal('8.97')),
#  (4, 'Greece', Decimal('1.99')),
#  (4, 'Greece', Decimal('0.99')),
#  (4, 'Germany', Decimal('32.97')),
#  (4, 'Germany', Decimal('8.99')),
#  (4, 'Germany', Decimal('7.99')),
#  (4, 'Germany', Decimal('41.94')),
#  (4, 'Germany', Decimal('29.95')),
#  (4, 'Germany', Decimal('99.80')),
#  (4, 'Germany', Decimal('15.96')),
#  (4, 'Germany', Decimal('71.76')),
#  (4, 'Germany', Decimal('3.98')),
#  (4, 'Germany', Decimal('12.87')),
#  (4, 'Gambia', Decimal('7.99')),
#  (4, 'Gambia', Decimal('5.99')),
#  (4, 'Gambia', Decimal('14.97')),
#  (4, 'Gambia', Decimal('3.99')),
#  (4, 'Gambia', Decimal('8.97')),
#  (4, 'Gambia', Decimal('2.97')),
#  (4, 'French Polynesia', Decimal('15.98')),
#  (4, 'French Polynesia', Decimal('44.91')),
#  (4, 'French Polynesia', Decimal('7.98')),
#  (4, 'French Polynesia', Decimal('11.96')),
#  (4, 'French Polynesia', Decimal('1.99')),
#  (4, 'French Polynesia', Decimal('2.97')),
#  (4, 'French Guiana', Decimal('6.99')),
#  (4, 'French Guiana', Decimal('5.99')),
#  (4, 'French Guiana', Decimal('9.98')),
#  (4, 'French Guiana', Decimal('11.97')),
#  (4, 'French Guiana', Decimal('1.99')),
#  (4, 'French Guiana', Decimal('0.99')),
#  (4, 'France', Decimal('23.97')),
#  (4, 'France', Decimal('34.95')),
#  (4, 'France', Decimal('35.94')),
#  (4, 'France', Decimal('54.89')),
#  (4, 'France', Decimal('15.96')),
#  (4, 'France', Decimal('23.92')),
#  (4, 'France', Decimal('3.98')),
#  (4, 'France', Decimal('5.94')),
#  (4, 'Finland', Decimal('7.99')),
#  (4, 'Finland', Decimal('5.99')),
#  (4, 'Finland', Decimal('3.99')),
#  (4, 'Finland', Decimal('11.96')),
#  (4, 'Finland', Decimal('2.97')),
#  (4, 'Faroe Islands', Decimal('17.98')),
#  (4, 'Faroe Islands', Decimal('7.99')),
#  (4, 'Faroe Islands', Decimal('9.98')),
#  (4, 'Faroe Islands', Decimal('11.96')),
#  (4, 'Faroe Islands', Decimal('2.97')),
#  (4, 'Ethiopia', Decimal('9.99')),
#  (4, 'Ethiopia', Decimal('8.97')),
#  (4, 'Ethiopia', Decimal('1.99')),
#  (4, 'Ethiopia', Decimal('2.97')),
#  (4, 'Estonia', Decimal('6.99')),
#  (4, 'Estonia', Decimal('4.99')),
#  (4, 'Estonia', Decimal('3.99')),
#  (4, 'Estonia', Decimal('8.97')),
#  (4, 'Estonia', Decimal('1.99')),
#  (4, 'Estonia', Decimal('0.99')),
#  (4, 'Egypt', Decimal('29.97')),
#  (4, 'Egypt', Decimal('26.97')),
#  (4, 'Egypt', Decimal('23.97')),
#  (4, 'Egypt', Decimal('20.97')),
#  (4, 'Egypt', Decimal('41.93')),
#  (4, 'Egypt', Decimal('59.88')),
#  (4, 'Egypt', Decimal('7.98')),
#  (4, 'Egypt', Decimal('47.84')),
#  (4, 'Egypt', Decimal('11.94')),
#  (4, 'Egypt', Decimal('9.90')),
#  (4, 'Ecuador', Decimal('9.99')),
#  (4, 'Ecuador', Decimal('8.99')),
#  (4, 'Ecuador', Decimal('39.95')),
#  (4, 'Ecuador', Decimal('13.98')),
#  (4, 'Ecuador', Decimal('5.99')),
#  (4, 'Ecuador', Decimal('29.94')),
#  (4, 'Ecuador', Decimal('27.93')),
#  (4, 'Ecuador', Decimal('17.94')),
#  (4, 'Ecuador', Decimal('3.98')),
#  (4, 'Ecuador', Decimal('7.92')),
#  (4, 'Dominican Republic', Decimal('10.99')),
#  (4, 'Dominican Republic', Decimal('9.99')),
#  (4, 'Dominican Republic', Decimal('8.99')),
#  (4, 'Dominican Republic', Decimal('7.99')),
#  (4, 'Dominican Republic', Decimal('6.99')),
#  (4, 'Dominican Republic', Decimal('17.97')),
#  (4, 'Dominican Republic', Decimal('44.91')),
#  (4, 'Dominican Republic', Decimal('20.93')),
#  (4, 'Dominican Republic', Decimal('1.99')),
#  (4, 'Dominican Republic', Decimal('4.95')),
#  (4, 'Czech Republic', Decimal('9.99')),
#  (4, 'Czech Republic', Decimal('7.99')),
#  (4, 'Czech Republic', Decimal('6.99')),
#  (4, 'Czech Republic', Decimal('11.98')),
#  (4, 'Czech Republic', Decimal('14.97')),
#  (4, 'Czech Republic', Decimal('14.95')),
#  (4, 'Czech Republic', Decimal('1.99')),
#  (4, 'Czech Republic', Decimal('1.98')),
#  (4, 'Congo, The Democratic Republic of the', Decimal('13.98')),
#  (4, 'Congo, The Democratic Republic of the', Decimal('5.99')),
#  (4, 'Congo, The Democratic Republic of the', Decimal('14.97')),
#  (4, 'Congo, The Democratic Republic of the', Decimal('8.97')),
#  (4, 'Congo, The Democratic Republic of the', Decimal('0.99')),
#  (4, 'Colombia', Decimal('19.98')),
#  (4, 'Colombia', Decimal('17.98')),
#  (4, 'Colombia', Decimal('39.95')),
#  (4, 'Colombia', Decimal('41.94')),
#  (4, 'Colombia', Decimal('41.93')),
#  (4, 'Colombia', Decimal('79.84')),
#  (4, 'Colombia', Decimal('27.93')),
#  (4, 'Colombia', Decimal('32.89')),
#  (4, 'Colombia', Decimal('5.97')),
#  (4, 'Colombia', Decimal('12.87')),
#  (4, 'China', Decimal('32.97')),
#  (4, 'China', Decimal('109.89')),
#  (4, 'China', Decimal('134.85')),
#  (4, 'China', Decimal('175.78')),
#  (4, 'China', Decimal('265.62')),
#  (4, 'China', Decimal('233.61')),
#  (4, 'China', Decimal('668.66')),
#  (4, 'China', Decimal('179.55')),
#  (4, 'China', Decimal('415.61')),
#  (4, 'China', Decimal('69.65')),
#  (4, 'China', Decimal('118.80')),
#  (4, 'Chile', Decimal('9.99')),
#  (4, 'Chile', Decimal('7.99')),
#  (4, 'Chile', Decimal('20.97')),
#  (4, 'Chile', Decimal('11.98')),
#  (4, 'Chile', Decimal('24.95')),
#  (4, 'Chile', Decimal('11.97')),
#  (4, 'Chile', Decimal('8.97')),
#  (4, 'Chile', Decimal('4.95')),
#  (4, 'Chad', Decimal('8.99')),
#  (4, 'Chad', Decimal('13.98')),
#  (4, 'Chad', Decimal('14.97')),
#  (4, 'Chad', Decimal('8.97')),
#  (4, 'Chad', Decimal('1.98')),
#  (4, 'Canada', Decimal('19.98')),
#  (4, 'Canada', Decimal('15.98')),
#  (4, 'Canada', Decimal('13.98')),
#  (4, 'Canada', Decimal('47.92')),
#  (4, 'Canada', Decimal('59.88')),
#  (4, 'Canada', Decimal('15.96')),
#  (4, 'Canada', Decimal('29.90')),
#  (4, 'Canada', Decimal('1.99')),
#  (4, 'Canada', Decimal('14.85')),
#  (4, 'Cameroon', Decimal('7.99')),
#  (4, 'Cameroon', Decimal('6.99')),
#  (4, 'Cameroon', Decimal('11.98')),
#  (4, 'Cameroon', Decimal('24.95')),
#  (4, 'Cameroon', Decimal('14.95')),
#  (4, 'Cameroon', Decimal('3.98')),
#  (4, 'Cameroon', Decimal('2.97')),
#  (4, 'Cambodia', Decimal('17.98')),
#  (4, 'Cambodia', Decimal('20.97')),
#  (4, 'Cambodia', Decimal('5.99')),
#  (4, 'Cambodia', Decimal('29.94')),
#  (4, 'Cambodia', Decimal('7.98')),
#  (4, 'Cambodia', Decimal('11.96')),
#  (4, 'Cambodia', Decimal('1.99')),
#  (4, 'Cambodia', Decimal('4.95')),
#  (4, 'Bulgaria', Decimal('17.98')),
#  (4, 'Bulgaria', Decimal('7.99')),
#  (4, 'Bulgaria', Decimal('6.99')),
#  (4, 'Bulgaria', Decimal('19.96')),
#  (4, 'Bulgaria', Decimal('14.95')),
#  (4, 'Bulgaria', Decimal('1.99')),
#  (4, 'Bulgaria', Decimal('1.98')),
#  (4, 'Brunei', Decimal('39.92')),
#  (4, 'Brunei', Decimal('11.96')),
#  (4, 'Brunei', Decimal('1.99')),
#  (4, 'Brunei', Decimal('5.94')),
#  (4, 'Brazil', Decimal('11.99')),
#  (4, 'Brazil', Decimal('32.97')),
#  (4, 'Brazil', Decimal('49.95')),
#  (4, 'Brazil', Decimal('71.92')),
#  (4, 'Brazil', Decimal('135.83')),
#  (4, 'Brazil', Decimal('160.77')),
#  (4, 'Brazil', Decimal('209.65')),
#  (4, 'Brazil', Decimal('389.22')),
#  (4, 'Brazil', Decimal('91.77')),
#  (4, 'Brazil', Decimal('170.43')),
#  (4, 'Brazil', Decimal('21.89')),
#  (4, 'Brazil', Decimal('59.40')),
#  (4, 'Bolivia', Decimal('8.99')),
#  (4, 'Bolivia', Decimal('6.99')),
#  (4, 'Bolivia', Decimal('5.99')),
#  (4, 'Bolivia', Decimal('24.95')),
#  (4, 'Bolivia', Decimal('3.99')),
#  (4, 'Bolivia', Decimal('11.96')),
#  (4, 'Bolivia', Decimal('0.99')),
#  (4, 'Belarus', Decimal('9.99')),
#  (4, 'Belarus', Decimal('17.98')),
#  (4, 'Belarus', Decimal('31.96')),
#  (4, 'Belarus', Decimal('6.99')),
#  (4, 'Belarus', Decimal('11.98')),
#  (4, 'Belarus', Decimal('9.98')),
#  (4, 'Belarus', Decimal('15.96')),
#  (4, 'Belarus', Decimal('5.98')),
#  (4, 'Belarus', Decimal('1.99')),
#  (4, 'Belarus', Decimal('7.92')),
#  (4, 'Bangladesh', Decimal('17.98')),
#  (4, 'Bangladesh', Decimal('15.98')),
#  (4, 'Bangladesh', Decimal('41.94')),
#  (4, 'Bangladesh', Decimal('11.98')),
#  (4, 'Bangladesh', Decimal('34.93')),
#  (4, 'Bangladesh', Decimal('3.99')),
#  (4, 'Bangladesh', Decimal('20.93')),
#  (4, 'Bangladesh', Decimal('7.96')),
#  (4, 'Bangladesh', Decimal('7.92')),
#  (4, 'Bahrain', Decimal('5.99')),
#  (4, 'Bahrain', Decimal('39.92')),
#  (4, 'Bahrain', Decimal('8.97')),
#  (4, 'Bahrain', Decimal('1.98')),
#  (4, 'Azerbaijan', Decimal('10.99')),
#  (4, 'Azerbaijan', Decimal('7.99')),
#  (4, 'Azerbaijan', Decimal('13.98')),
#  (4, 'Azerbaijan', Decimal('11.98')),
#  (4, 'Azerbaijan', Decimal('44.91')),
#  (4, 'Azerbaijan', Decimal('3.99')),
#  (4, 'Azerbaijan', Decimal('8.97')),
#  (4, 'Azerbaijan', Decimal('1.99')),
#  (4, 'Azerbaijan', Decimal('4.95')),
#  (4, 'Austria', Decimal('8.99')),
#  (4, 'Austria', Decimal('15.98')),
#  (4, 'Austria', Decimal('17.97')),
#  (4, 'Austria', Decimal('39.92')),
#  (4, 'Austria', Decimal('7.98')),
#  (4, 'Austria', Decimal('20.93')),
#  (4, 'Austria', Decimal('5.94')),
#  (4, 'Armenia', Decimal('9.99')),
#  (4, 'Armenia', Decimal('7.99')),
#  (4, 'Armenia', Decimal('13.98')),
#  (4, 'Armenia', Decimal('5.99')),
#  (4, 'Armenia', Decimal('14.97')),
#  (4, 'Armenia', Decimal('14.95')),
#  (4, 'Armenia', Decimal('1.99')),
#  (4, 'Armenia', Decimal('0.99')),
#  (4, 'Argentina', Decimal('10.99')),
#  (4, 'Argentina', Decimal('29.97')),
#  (4, 'Argentina', Decimal('35.96')),
#  (4, 'Argentina', Decimal('71.91')),
#  (4, 'Argentina', Decimal('41.94')),
#  (4, 'Argentina', Decimal('65.89')),
#  (4, 'Argentina', Decimal('214.57')),
#  (4, 'Argentina', Decimal('27.93')),
#  (4, 'Argentina', Decimal('101.66')),
#  (4, 'Argentina', Decimal('15.92')),
#  (4, 'Argentina', Decimal('33.66')),
#  (4, 'Anguilla', Decimal('14.97')),
#  (4, 'Anguilla', Decimal('17.94')),
#  (4, 'Anguilla', Decimal('4.95')),
#  (4, 'Angola', Decimal('9.99')),
#  (4, 'Angola', Decimal('8.99')),
#  (4, 'Angola', Decimal('7.99')),
#  (4, 'Angola', Decimal('11.98')),
#  (4, 'Angola', Decimal('19.96')),
#  (4, 'Angola', Decimal('15.96')),
#  (4, 'Angola', Decimal('2.99')),
#  (4, 'Angola', Decimal('5.94')),
#  (4, 'American Samoa', Decimal('29.94')),
#  (4, 'American Samoa', Decimal('3.99')),
#  (4, 'American Samoa', Decimal('2.99')),
#  (4, 'American Samoa', Decimal('2.97')),
#  (4, 'Algeria', Decimal('10.99')),
#  (4, 'Algeria', Decimal('17.98')),
#  (4, 'Algeria', Decimal('41.94')),
#  (4, 'Algeria', Decimal('11.98')),
#  (4, 'Algeria', Decimal('34.93')),
#  (4, 'Algeria', Decimal('7.98')),
#  (4, 'Algeria', Decimal('35.88')),
#  (4, 'Algeria', Decimal('1.99')),
#  (4, 'Algeria', Decimal('6.93')),
#  (4, 'Afghanistan', Decimal('8.99')),
#  (4, 'Afghanistan', Decimal('20.97')),
#  (4, 'Afghanistan', Decimal('4.99')),
#  (4, 'Afghanistan', Decimal('2.97')),
#  (3, 'Zambia', Decimal('7.99')),
#  (3, 'Zambia', Decimal('6.99')),
#  (3, 'Zambia', Decimal('11.98')),
#  (3, 'Zambia', Decimal('19.96')),
#  (3, 'Zambia', Decimal('0.99')),
#  (3, 'Yugoslavia', Decimal('8.99')),
#  (3, 'Yugoslavia', Decimal('7.99')),
#  (3, 'Yugoslavia', Decimal('6.99')),
#  (3, 'Yugoslavia', Decimal('11.98')),
#  (3, 'Yugoslavia', Decimal('19.96')),
#  (3, 'Yugoslavia', Decimal('3.99')),
#  (3, 'Yugoslavia', Decimal('11.96')),
#  (3, 'Yugoslavia', Decimal('1.98')),
#  (3, 'Yemen', Decimal('10.99')),
#  (3, 'Yemen', Decimal('26.97')),
#  (3, 'Yemen', Decimal('7.99')),
#  (3, 'Yemen', Decimal('13.98')),
#  (3, 'Yemen', Decimal('5.99')),
#  (3, 'Yemen', Decimal('54.89')),
#  (3, 'Yemen', Decimal('11.97')),
#  (3, 'Yemen', Decimal('17.94')),
#  (3, 'Yemen', Decimal('1.99')),
#  (3, 'Yemen', Decimal('5.94')),
#  (3, 'Virgin Islands, U.S.', Decimal('6.99')),
#  (3, 'Virgin Islands, U.S.', Decimal('5.99')),
#  (3, 'Virgin Islands, U.S.', Decimal('4.99')),
#  (3, 'Virgin Islands, U.S.', Decimal('5.98')),
#  (3, 'Virgin Islands, U.S.', Decimal('1.99')),
#  (3, 'Vietnam', Decimal('9.99')),
#  (3, 'Vietnam', Decimal('35.96')),
#  ...]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>month</th>
#         <th>country</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Australia</td>
#         <td>2364.19</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Canada</td>
#         <td>2460.24</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>Australia</td>
#         <td>4895.10</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>Canada</td>
#         <td>4736.78</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>Australia</td>
#         <td>12060.33</td>
#     </tr>
# </tbody></table></div>

# %% [markdown]
# ## Revenue Total, by Month, by Country, by Month & Country All in one shot
#
# TODO: Write a query that calculates total revenue at the various grouping levels done above (total, by month, by country, by month & country) all at once using the grouping sets function. Your output should match the table below.

# %%
# %%sql
# SELECT ...
# FROM ...

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>month</th>
#         <th>country</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Australia</td>
#         <td>2364.19</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Canada</td>
#         <td>2460.24</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>None</td>
#         <td>4824.43</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>Australia</td>
#         <td>4895.10</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>Canada</td>
#         <td>4736.78</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>None</td>
#         <td>9631.88</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>Australia</td>
#         <td>12060.33</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>Canada</td>
#         <td>11826.23</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>None</td>
#         <td>23886.56</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>Australia</td>
#         <td>14136.07</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>Canada</td>
#         <td>14423.39</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>None</td>
#         <td>28559.46</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>Australia</td>
#         <td>271.08</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>Canada</td>
#         <td>243.10</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>None</td>
#         <td>514.18</td>
#     </tr>
#     <tr>
#         <td>None</td>
#         <td>None</td>
#         <td>67416.51</td>
#     </tr>
#     <tr>
#         <td>None</td>
#         <td>Australia</td>
#         <td>33726.77</td>
#     </tr>
#     <tr>
#         <td>None</td>
#         <td>Canada</td>
#         <td>33689.74</td>
#     </tr>
# </tbody></table></div>
